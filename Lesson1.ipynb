# %% [markdown]
# <a href="https://colab.research.google.com/github/chriswebb31/FastAI/blob/master/Lesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
from fastai import *
from fastai.vision import *
import matplotlib.pyplot as plt

# %%
help(untar_data)
# Out:
# Help on function untar_data in module fastai.datasets:
#
# untar_data(url:str, fname:Union[pathlib.Path, str]=None, dest:Union[pathlib.Path, str]=None, data=True, force_download=False, verbose=False) -> pathlib.Path
#     Download `url` to `fname` if `dest` doesn't exist, and un-tgz to folder `dest`.

# %%
path = untar_data(URLs.PETS); path
# Out:
# ...
# PosixPath('/root/.fastai/data/oxford-iiit-pet')

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/annotations')]

# %%
path_anno = path/'annotations'
path_img = path/'images'

# %%
fnames = get_image_files(path_img)
fnames[:5]
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_101.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_142.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_34.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/english_setter_194.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_160.jpg')]

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224)
data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (5912 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Abyssinian,american_bulldog,wheaten_terrier,american_bulldog,British_Shorthair
# Path: /root/.fastai/data/oxford-iiit-pet/images;
#
# Valid: LabelList (1478 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# scottish_terrier,Ragdoll,pomeranian,boxer,scottish_terrier
# Path: /root/.fastai/data/oxford-iiit-pet/images;
#
# Test: None

# %%
data.show_batch(rows=3, figsize=(7, 6))

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'boxer', 'chihuahua', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'miniature_pinscher', 'newfoundland', 'pomeranian', 'pug', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier']
# (37, 37)

# %% [markdown]
# # Training: resnet34

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.399137</td>
#       <td>0.327606</td>
#       <td>0.110961</td>
#       <td>01:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.608843</td>
#       <td>0.304133</td>
#       <td>0.094723</td>
#       <td>01:52</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.397912</td>
#       <td>0.247529</td>
#       <td>0.077808</td>
#       <td>01:52</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.283675</td>
#       <td>0.244178</td>
#       <td>0.078484</td>
#       <td>01:53</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage_1')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(15, 11))

# %%
doc(interp.plot_top_losses)
# Out:
# <h4 id="_cl_int_plot_top_losses" class="doc_header"><code>_cl_int_plot_top_losses</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/learner.py#L166" class="source_link" style="float:right">[source]</a><a class="source_link" data-toggle="collapse" data-target="#_cl_int_plot_top_losses-pytest" style="float:right; padding-right:10px">[test]</a></h4><blockquote><p><code>_cl_int_plot_top_losses</code>(<strong><code>k</code></strong>, <strong><code>largest</code></strong>=<strong><em><code>True</code></em></strong>, <strong><code>figsize</code></strong>=<strong><em><code>(12, 12)</code></em></strong>, <strong><code>heatmap</code></strong>:<code>bool</code>=<strong><em><code>False</code></em></strong>, <strong><code>heatmap_thresh</code></strong>:<code>int</code>=<strong><em><code>16</code></em></strong>, <strong><code>alpha</code></strong>:<code>float</code>=<strong><em><code>0.6</code></em></strong>, <strong><code>cmap</code></strong>:<code>str</code>=<strong><em><
# ...

# %%
interp.plot_confusion_matrix(figsize=(12, 12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('american_pit_bull_terrier', 'staffordshire_bull_terrier', 9),
#  ('american_pit_bull_terrier', 'american_bulldog', 6),
#  ('Ragdoll', 'Birman', 5),
#  ('Siamese', 'Birman', 5),
#  ('Maine_Coon', 'Ragdoll', 4),
#  ('american_bulldog', 'staffordshire_bull_terrier', 4),
#  ('British_Shorthair', 'Russian_Blue', 3),
#  ('Russian_Blue', 'Bombay', 3),
#  ('Russian_Blue', 'British_Shorthair', 3),
#  ('english_cocker_spaniel', 'english_setter', 3),
#  ('miniature_pinscher', 'american_pit_bull_terrier', 3),
#  ('miniature_pinscher', 'chihuahua', 3),
#  ('Bengal', 'Abyssinian', 2),
#  ('Maine_Coon', 'Bengal', 2),
#  ('Persian', 'Maine_Coon', 2),
#  ('Persian', 'Ragdoll', 2),
#  ('Ragdoll', 'Maine_Coon', 2),
#  ('american_pit_bull_terrier', 'beagle', 2),
#  ('american_pit_bull_terrier', 'boxer', 2),
#  ('beagle', 'basset_hound', 2),
#  ('chihuahua', 'miniature_pinscher', 2),
#  ('miniature_pinscher', 'Sphynx', 2),
#  ('staffordshire_bull_terrier', 'american_bulldog', 2),
# ...

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.690046</td>
#       <td>0.374757</td>
#       <td>0.121786</td>
#       <td>01:58</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage_1')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (5912 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Abyssinian,american_bulldog,wheaten_terrier,american_bulldog,British_Shorthair
# Path: /root/.fastai/data/oxford-iiit-pet/images;
#
# Valid: LabelList (1478 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# scottish_terrier,Ragdoll,pomeranian,boxer,scottish_terrier
# Path: /root/.fastai/data/oxford-iiit-pet/images;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
# ...

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.230798</td>
#       <td>0.235762</td>
#       <td>0.077808</td>
#       <td>01:57</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.220910</td>
#       <td>0.228202</td>
#       <td>0.073072</td>
#       <td>01:59</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Training: Resnet50

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=299, bs=48)
data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (5912 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# Abyssinian,american_bulldog,wheaten_terrier,english_setter,american_bulldog
# Path: /root/.fastai/data/oxford-iiit-pet/images;
#
# Valid: LabelList (1478 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# samoyed,Bengal,american_bulldog,Sphynx,leonberger
# Path: /root/.fastai/data/oxford-iiit-pet/images;
#
# Test: None

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# ...

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.756551</td>
#       <td>0.311612</td>
#       <td>0.095399</td>
#       <td>03:35</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.443729</td>
#       <td>0.293494</td>
#       <td>0.092016</td>
#       <td>03:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.296426</td>
#       <td>0.250014</td>
#       <td>0.081191</td>
#       <td>03:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.184388</td>
#       <td>0.206261</td>
#       <td>0.070365</td>
#       <td>03:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.135584</td>
#       <td>0.179875</td>
#       <td>0.060216</td>
#       <td>03:25</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-50')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.most_confused(min_val=2)
# Out:
# [('american_pit_bull_terrier', 'staffordshire_bull_terrier', 9),
#  ('Egyptian_Mau', 'Bengal', 5),
#  ('american_bulldog', 'staffordshire_bull_terrier', 5),
#  ('staffordshire_bull_terrier', 'american_pit_bull_terrier', 5),
#  ('Ragdoll', 'Birman', 4),
#  ('Bengal', 'Abyssinian', 3),
#  ('Bengal', 'Egyptian_Mau', 3),
#  ('Birman', 'Ragdoll', 3),
#  ('chihuahua', 'miniature_pinscher', 3),
#  ('British_Shorthair', 'Russian_Blue', 2),
#  ('Egyptian_Mau', 'Abyssinian', 2),
#  ('Maine_Coon', 'Abyssinian', 2),
#  ('Persian', 'Ragdoll', 2),
#  ('Siamese', 'Birman', 2),
#  ('american_pit_bull_terrier', 'american_bulldog', 2),
#  ('american_pit_bull_terrier', 'miniature_pinscher', 2),
#  ('boxer', 'american_bulldog', 2),
#  ('boxer', 'basset_hound', 2),
#  ('boxer', 'staffordshire_bull_terrier', 2),
#  ('english_cocker_spaniel', 'havanese', 2)]

# %%
path = untar_data(URLs.MNIST_SAMPLE); path
# Out:
# ...
# PosixPath('/root/.fastai/data/mnist_sample')

# %%
tfms = get_transforms(do_flip=False)
data = ImageDataBunch.from_folder(path, ds_tfms=tfms, size=36)

# %%
data.show_batch(rows=3, figsize=(5,5))

# %%
df = pd.read_csv(path/'labels.csv')
df.head()
# Out:
#                 name  label
# 0   train/3/7463.png      0
# 1  train/3/21102.png      0
# 2  train/3/31559.png      0
# 3  train/3/46882.png      0
# 4  train/3/26209.png      0

# %%
data = ImageDataBunch.from_csv(path, ds_tfms=tfms, size=28)

# %%
data.show_batch(rows=3, figsize=(5,5))
data.classes
# Out:
# [0, 1]

# %% [markdown]
# # Classifying Scenes

# %%
train_path = '/content/gdrive/My Drive/Data/intel-image-classification/seg_train'
test_path = '/content/gdrive/My Drive/Data/intel-image-classification/seg_test'
prediction_path = '/content/gdrive/My Drive/Data/intel-image-classification/seg_pred'

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(train_path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street'],
#  6,
#  11228,
#  2806)

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.566328</td>
#       <td>0.362261</td>
#       <td>0.117962</td>
#       <td>40:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.385749</td>
#       <td>0.261801</td>
#       <td>0.094084</td>
#       <td>01:35</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.284087</td>
#       <td>0.239053</td>
#       <td>0.080542</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.237357</td>
#       <td>0.204506</td>
#       <td>0.073058</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.206801</td>
#       <td>0.201364</td>
#       <td>0.070919</td>
#       <td>01:33</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('scene-1')

# %%
learn.export()

# %%
learn.load('scene-1')
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-6, 1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.222843</td>
#       <td>0.185027</td>
#       <td>0.064148</td>
#       <td>25:54</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.168217</td>
#       <td>0.173139</td>
#       <td>0.053813</td>
#       <td>02:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('scene-2')

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.fit_one_cycle(2, max_lr=1e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.139307</td>
#       <td>0.171482</td>
#       <td>0.056308</td>
#       <td>02:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.114696</td>
#       <td>0.169944</td>
#       <td>0.055239</td>
#       <td>02:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
defaults.device = torch.device('cpu')

# %%
learn = load_learner(train_path)

# %%
pred_class,pred_idx,outputs = learn.predict(open_image(prediction_path + '/seg_pred/' + '3.jpg'))
pred_class,pred_idx,outputs
# Out:
# (Category tensor(5),
#  tensor(5),
#  tensor([9.9456e-05, 5.4793e-07, 2.1386e-09, 4.2559e-10, 8.1388e-09, 9.9990e-01]))

# %%
img = open_image(prediction_path + '/seg_pred/3.jpg')

# %%
learn.data.classes
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']
